# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import dask.dataframe as dd
from geopy.distance import geodesic
import string

import warnings
warnings.filterwarnings('ignore')

# %%
###EDA

# %%
dir = '../csv/'
fname = 'credit_card_fraud_sample_2019_Dec_100K'

df_eda = pd.read_pickle(fname + '_prepared.pkl')

# %%
df_eda.head()
# Out:
#          id          ssn            cc_num     first      last  gender  \
# 0  18832098  087-12-2118      639017474813   Zachary     Parks       1
# 1  24801519  267-50-6963  6567701540795312    Jeremy      Soto       1
# 2  31141574  411-62-3428   180022197664580    Samuel  Mcdonald       1
# 3  25784982  841-48-6189  3584095374557286  Nicholas     Davis       1
# 4  19821729  603-28-2907  6011226654586127      Mark   Sanchez       1
#
#                        street        city state    zip  ...  is_fraud  \
# 0  94238 Jacob Cliff Apt. 458    Columbia    MO  65203  ...         0
# 1          29865 Bush Centers  Goldendale    WA  98620  ...         0
# 2           4570 Ruth Harbors   Palo Alto    CA  94306  ...         0
# 3       83759 Shannon Meadows      Kohler    WI  53044  ...         0
# 4            21975 Pam Garden  Birmingham    MI  48009  ...         0
#
#                       merchant  merch_lat  merch_long  \
# 0  turcotte, mckenzie and koss  37.978633  -91.813002
# 1             hermann and sons  45.829641 -121.389115
# 2                   conroy ltd  37.825064 -121.644324
# 3                 hudson-grady  43.686522  -86.947295
# 4                   dooley inc  43.031478  -83.903585
#
#                                  col   region trans_time_segment    age_group  \
# 0  fraud_Turcotte, McKenzie and Koss  Midwest       Morning_6-12  middle_aged
# 1             fraud_Hermann and Sons     West      Evening_18-24  young_adult
# 2                   fraud_Conroy Ltd     West    Afternoon_12-18  young_adult
# 3                 fraud_Hudson-Grady  Midwest       Morning_6-12  young_adult
# 4                   fraud_Dooley Inc  Midwest      Evening_18-24     teenager
#
#    cc_type area_cat
# 0  Maestro    urban
# 1  Maestro    urban
# 2  Unknown    urban
# 3      JCB    rural
# 4  Maestro    urban
#
# [5 rows x 33 columns]
